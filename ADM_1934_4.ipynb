# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil-gitub/ADMB_27/blob/main/ADM_1934_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([2,3,5,6,7,9,8,7,2,8,9])
plt.plot(xpoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0, 1, 2, 3, 4, 5])
ypoints = np.array([3,8,1,10,5,7])
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 1, 2, 3, 4, 5])
ypoints = np.array([3,8,1,10,5,7])
ypoints = np.array([2,8,6,9,4,7])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'royalblue', mfc = 'yellow')
plt.plot(ypoints, linestyle = ':')
plt.plot(ypoints, color ='r')
plt.plot(ypoints, linewidth = '20.5')
plt.plot(xpoints,ypoints,'o:b')
plt.show()
plt.plot(xpoints,ypoints,'o:b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = np.array([0,1,2,3])
y1 = np.array([3,8,1,10])
x2 = np.array([0,1,2,3])
y2 = np.array([6,2,7,11])
plt.plot(x1,y1,x2,y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = np.array(["A","B","C","D"])
y1 = np.array([3,8,1,10])
plt.bar(x1,y1)
plt.show()

# %%
plt.grid()
import numpy as np
plt.grid(axis = 'x')
plt.grid(axis = 'y')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4])
y = np.array([5, 6, 7, 8])

plt.plot(x, y)
plt.title("Bar Chart Example")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
x1=np.array([0,1,2,3])
y1=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x1,y1)
x2=np.array([0,1,2,3])
y2=np.array([10,1,6,8])
plt.subplot(2,1,2)
plt.plot(x2,y2)
plt.show()

# %%
y = np.array([35,25,25,15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = mylabels,explode=myexplode)
plt.show()
